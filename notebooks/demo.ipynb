# %%
from agents import coordinator
artifacts = coordinator.orchestrate("Run baseline and EV scenarios")
artifacts['impact_report']

# %%
import json, pathlib
path = pathlib.Path('storage/reports/latest_report.json')
print(path.read_text()) if path.exists() else print('Report missing')
